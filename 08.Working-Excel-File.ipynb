# %%
import pandas as pd

# %% [markdown]
# ### Read excel file

# %%
excel_file = pd.ExcelFile('./DataSets/excel_students.xls')
print(excel_file.sheet_names)

df = excel_file.parse('Sheet1')
df
# Out:
# ['Sheet1', 'Sheet2']
#    student_name                    school_name               address  \
# 0       Aleshia        Alan D Rosenburg Cpa Pc          14 Taylor St
# 1          Evan             Cap Gemini America           5 Binney St
# 2        France            Elliott, John W Esq          8 Moor Place
# 3       Ulysses                 Mcmahan, Ben L         505 Exeter Rd
# 4        Tyisha                 Champagne Room     5396 Forth Street
# 5          Eric        Thompson, Michael C Esq          9472 Lind St
# 6          Marg  Wrangle Hill Auto Auct & Slvg      7457 Cowl St #70
# 7       Laquita          In Communications Inc  20 Gloucester Pl #96
# 8          Lura                Bizerba Usa Inc      929 Augustine St
# 9        Yuette                      Max Video  45 Bradfield St #166
# 10     Fernanda           K & R Associates Inc    620 Northampton St
# 11  Charlesetta               Cain, John M Esq           5 Hygeia St
# ...

# %%
# Read all sheets of excel file
all_sheets = pd.read_excel('./DataSets/excel_students.xls', sheet_name=None)
all_sheets
# Out:
# {'Sheet1':    student_name                    school_name               address  \
#  0       Aleshia        Alan D Rosenburg Cpa Pc          14 Taylor St
#  1          Evan             Cap Gemini America           5 Binney St
#  2        France            Elliott, John W Esq          8 Moor Place
#  3       Ulysses                 Mcmahan, Ben L         505 Exeter Rd
#  4        Tyisha                 Champagne Room     5396 Forth Street
#  5          Eric        Thompson, Michael C Esq          9472 Lind St
#  6          Marg  Wrangle Hill Auto Auct & Slvg      7457 Cowl St #70
#  7       Laquita          In Communications Inc  20 Gloucester Pl #96
#  8          Lura                Bizerba Usa Inc      929 Augustine St
#  9        Yuette                      Max Video  45 Bradfield St #166
#  10     Fernanda           K & R Associates Inc    620 Northampton St
#  11  Charlesetta               Cain, John M Esq           5 Hygeia St
# ...

# %%
# read specific sheet
sheetObj = pd.read_excel('./DataSets/excel_students.xls', sheet_name='Sheet2')
sheetObj.head()
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal         phone  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01944-369967
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01714-737668
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01935-821636
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01302-601380
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01290-367248
#
#                         email                                   web
# ...

# %% [markdown]
# ### Write to excel file

# %%
df = pd.DataFrame({'States':['California', 'Florida', 'Montana', 'Colorodo', 'Washington', 'Virginia'],
    'Capitals':['Sacramento', 'Tallahassee', 'Helena', 'Denver', 'Olympia', 'Richmond'],
    'Population':['508529', '193551', '32315', '619968', '52555', '227032']})

df.to_excel('excelWrite.xlsx', sheet_name='StateSheet', index=False)

# %%
# Write to multiple sheets
income1 = pd.DataFrame({'Names': ['Stephen', 'Camilla', 'Tom'],
                   'Salary':[100000, 70000, 60000]})

income2 = pd.DataFrame({'Names': ['Pete', 'April', 'Marty'],
                   'Salary':[120000, 110000, 50000]})

income3 = pd.DataFrame({'Names': ['Victor', 'Victoria', 'Jennifer'],
                   'Salary':[75000, 90000, 40000]})

writer = pd.ExcelWriter('income.xlsx', engine='xlsxwriter')

income1.to_excel(writer, sheet_name="Income1")
income2.to_excel(writer, sheet_name="Income2")
income3.to_excel(writer, sheet_name="Income3")

writer.close()
